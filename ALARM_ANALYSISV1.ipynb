# %%
import pandas as pd
from google.colab import files

# Upload file
uploaded = files.upload()

# Automatically get filename
filename = list(uploaded.keys())[0]

# Load Excel (assuming header starts from 4th row)
df = pd.read_excel(filename,header=3)

# Force all column names to string and clean
df.columns = [str(col).strip().lower().replace(" ", "_") for col in df.columns]

# Combine date and time if both exist
if 'event_date' in df.columns and 'event_time' in df.columns:
    df['event_datetime'] = pd.to_datetime(df['event_date'].astype(str) + ' ' + df['event_time'].astype(str), errors='coerce')
    df['hour'] = df['event_datetime'].dt.hour
    df['day'] = df['event_datetime'].dt.day_name()
else:
    print("Column names not found: 'event_date' or 'event_time'")

# Display top rows
df.head(500)
# Out:
#      <input type="file" id="files-be250119-7ce5-4156-8918-172e21943234" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be250119-7ce5-4156-8918-172e21943234">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head(500)
# Out:
#     sl_no. client_name client_domain                              event_id  \
# 0      376         UAE  americanauae  5724487d-301e-4820-b88c-285ad64298c9
# 1      377         UAE  americanauae  bfe7a4dc-706b-4631-b3af-e553befa9739
# 2      378         UAE  americanauae  cd888351-0806-4135-ad68-7191edc28316
# 3      379         UAE  americanauae  a59d77b1-3322-46cb-8516-304e5ce8ecd9
# 4      380         UAE  americanauae  c20fb1d2-05f7-46de-aa50-4f96dc933ad6
# 5      381         UAE  americanauae  bf3de922-5f2e-4982-8de2-5975e3d4b46f
# 6      382         UAE  americanauae  e1218097-8f29-3675-bece-6e09b042c30e
# 7      383         KSA  americanaksa  45e1725f-e854-3bb6-a478-410524254a2d
# 8      384         KSA  americanaksa  2c1d1472-995c-3a3d-9475-fb2e469bedf1
# 9      385         KSA  americanaksa  05666566-128d-3b6e-aa12-6389cbacac5f
# 10     386         UAE  americanauae  a78167cd-85e0-37a9-a382-d940cf73a0ef
# ...

# %%
df.columns = [str(col).strip().lower().replace(" ", "_") for col in df.columns]
print(df.columns.tolist())
# Out:
# ['sl_no.', 'client_name', 'event_id', 'event_date', 'event_time', 'source_id', 'source_name', 'source_type_name', 'group', 'name', 'points', 'path', 'criticality', 'type', 'action', 'asset_code', 'issue', 'active', 'alarm_message', 'configuration_id', 'resolved_date', 'resolved_time', 'resolved_message', 'delay_(long)', 'event_date_and_time', 'resolved_date_and_time', 'time_taken_to_resolve', 'event_datetime', 'hour', 'day']

# %%
df['source_name'].value_counts().head(10)
# Out:
# source_name
# K 5512180 FZ 01                           2
# KFC Abdul Nasser New - 112750             1
# Hardees Khorfakkan Relocation - 114922    1
# Hardees Barsha Grand Lube - 114742        1
# Pizza Hut Grand Lube - 116803             1
# Pizza Hut Fujerah - 116724                1
# Pizza Hut Dubai - Abu Dhabi - 116726      1
# P 116957 CH 01                            1
# H 5514144 EM 01                           1
# H 5514434 FZ 01                           1
# Name: count, dtype: int64

# %%
# Count all alarm sources
alarm_sources = df['source_name'].value_counts()

# Print all source names with their alarm counts
print(alarm_sources)
# Out:
# source_name
# K 5512180 FZ 01                           2
# KFC Abdul Nasser New - 112750             1
# Hardees Khorfakkan Relocation - 114922    1
# Hardees Barsha Grand Lube - 114742        1
# Pizza Hut Grand Lube - 116803             1
# Pizza Hut Fujerah - 116724                1
# Pizza Hut Dubai - Abu Dhabi - 116726      1
# P 116957 CH 01                            1
# H 5514144 EM 01                           1
# H 5514434 FZ 01                           1
# K 112125 FZ 01                            1
# K 5512224 CH 02                           1
# K 5512113 FZ 01                           1
# K 5512215 FZ 01                           1
# K 5512741 CH 01                           1
# K 5512443 FZ 01                           1
# K 112947 FZ 01                            1
# H 5514419 FZ 01                           1
# T 5518103 CH 01                           1
# K 5512415 FZ 01                           1
# H 5514416 FZ 01                           1
# ...

# %%
import matplotlib.pyplot as plt

# Plot the alarm sources in descending order
plt.figure(figsize=(12, 90))  # Increased height for better readability
ax = df['source_name'].value_counts().sort_values(ascending=False).plot(kind='barh', color='skyblue')

# Add values on top of each bar
for p in ax.patches:
    ax.annotate(f'{p.get_width():.0f}',
                (p.get_x() + p.get_width(), p.get_y() + p.get_height() / 2.),
                ha='left', va='center', fontsize=9,
                xytext=(3, 0), textcoords='offset points')

plt.xlabel("Number of Alarms")
plt.ylabel("Alarm Source")
plt.title("Alarm Counts by Source")
plt.tight_layout()
plt.show()

# %%
client_alarms = df['client_name'].value_counts()

# Display the count
print(client_alarms)
# Out:
# client_name
# KSA    17
# UAE    14
# Name: count, dtype: int64

# %%
client_alarms = df['client_name'].value_counts()

# Display the count
print(client_alarms)
# Out:
# client_name
# KSA    17
# UAE    14
# Name: count, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Count alarms per client and convert to DataFrame
client_alarms = df['client_name'].value_counts().reset_index()
client_alarms.columns = ['client_name', 'alarm_count']

# %%
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=client_alarms, x='client_name', y='alarm_count', palette='Set2')

plt.title("Total Alarms per Client (Different Colors)")
plt.xlabel("Client Name")
plt.ylabel("Alarm Count")
plt.xticks(rotation=45, ha='right')

# Add values on top of each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height()}',
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                fontsize=10, color='black',
                xytext=(0, 5), textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-11-79bfe89f9ecc>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=client_alarms, x='client_name', y='alarm_count', palette='Set2')

# %%
#Count alarms by source_type_name
source_type_alarms = df['source_type_name'].value_counts().reset_index()
source_type_alarms.columns = ['source_type_name', 'alarm_count']

# %%
source_type_alarms= df['source_type_name'].value_counts()
print(source_type_alarms)
# Out:
# source_type_name
# Freezer             15
# Chiller              9
# Commercial Tower     6
# LV Panel Meter       1
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Count alarms by source_type_name
source_type_alarms = df['source_type_name'].value_counts().reset_index()
source_type_alarms.columns = ['source_type_name', 'alarm_count']

# Plot
plt.figure(figsize=(12, 5))
ax = sns.barplot(data=source_type_alarms, x='source_type_name', y='alarm_count', palette='Set3')

plt.title("Alarm Count by Source Type (Different Colors)")
plt.xlabel("Source Type Name")
plt.ylabel("Alarm Count")
plt.xticks(rotation=45, ha='right')

# Add values on top of each bar
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}',
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom',
                fontsize=10, color='black',
                xytext=(0, 5), textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-14-1b92c622e028>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=source_type_alarms, x='source_type_name', y='alarm_count', palette='Set3')

# %%
# Count alarms per condition and convert to DataFrame
condition_alarms = df['name'].value_counts().reset_index()
condition_alarms.columns = ['name', 'alarm_count']

# Plot the data
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=condition_alarms, x='name', y='alarm_count', palette='Set1')

plt.title("Total Alarms by Condition (Different Colors)")
plt.xlabel("Condition Name")
plt.ylabel("Alarm Count")
plt.xticks(rotation=45, ha='right')

# Add values on top of each bar
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}',
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom',
                fontsize=10, color='black',
                xytext=(0, 5), textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-15-d6347f11cf30>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=condition_alarms, x='name', y='alarm_count', palette='Set1')

# %%
criticality_counts = df['criticality'].value_counts().reset_index()
criticality_counts.columns = ['criticality', 'alarm_count']

plt.figure(figsize=(8, 5))
ax = sns.barplot(data=criticality_counts, x='criticality', y='alarm_count', palette='coolwarm')

plt.title("Alarm Count by Criticality")
plt.xlabel("Criticality Level")
plt.ylabel("Alarm Count")

# Annotate bar values
for p in ax.patches:
    ax.annotate(f'{p.get_height()}',
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                fontsize=10, color='black',
                xytext=(0, 5), textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-16-9945eda70eea>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=criticality_counts, x='criticality', y='alarm_count', palette='coolwarm')
